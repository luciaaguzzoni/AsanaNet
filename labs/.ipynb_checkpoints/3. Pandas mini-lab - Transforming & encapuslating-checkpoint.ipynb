# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # EXERCISE 📝: Loading, transforming, exporting & encapsulating

# %% [markdown]
# 1. **READ** the sperstore.csv dataset from the datasets folder (beware of absolute and relative paths!). Know where you are.
#
# - How can I know where did I open this notebook? Remember bash syntax can be used through jupyter

# %%
dataset = pd.read_csv("../Documents/Ironhack/bootcamp/lectures/datasets/superstore.csv")
df = pd.DataFrame(dataset)
df.head()
# Out:
#    Row ID        Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156    11/8/17  11/11/17    Second Class    CG-12520
# 1       2  CA-2017-152156    11/8/17  11/11/17    Second Class    CG-12520
# 2       3  CA-2017-138688    6/12/17   6/16/17    Second Class    DV-13045
# 3       4  US-2016-108966   10/11/16  10/18/16  Standard Class    SO-20335
# 4       5  US-2016-108966   10/11/16  10/18/16  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# 0     42420.0   South  FUR-BO-10001798        Furniture    Bookcases
# 1     42420.0   South  FUR-CH-10000454        Furniture       Chairs
# 2     90036.0    West  OFF-LA-10000240  Office Supplies       Labels
# 3     33311.0   South  FUR-TA-10000577        Furniture       Tables
# 4     33311.0   South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164
#
# [5 rows x 21 columns]

# %% [markdown]
# 2. **RENAME** the columns: make them all into lower case AND substitute spaces for inderscores. Eg.: `Order ID` -> `order_id`

# %%
df.columns = [i.lower().replace(" ","_") for i in df.columns]
df.sample()
# Out:
#       row_id        order_id order_date ship_date     ship_mode customer_id  \
# 7155    7156  US-2016-136749   12/25/16  12/27/16  Second Class    LH-16900
#
#        customer_name   segment        country      city  ... postal_code  \
# 7155  Lena Hernandez  Consumer  United States  Columbus  ...     31907.0
#
#       region       product_id         category sub-category     product_name  \
# 7155   South  OFF-BI-10004492  Office Supplies      Binders  Tuf-Vin Binders
#
#       sales  quantity  discount  profit
# 7155  157.9         5       0.0  74.213
#
# [1 rows x 21 columns]

# %% [markdown]
# 3. **DROP** the `Row ID` column

# %%
df.drop(columns="row_id",inplace=True)
df.sample()
# Out:
#             order_id order_date ship_date       ship_mode customer_id  \
# 1401  CA-2017-159212    11/1/17   11/5/17  Standard Class    KM-16375
#
#          customer_name      segment        country   city     state  \
# 1401  Katherine Murray  Home Office  United States  Salem  Virginia
#
#       postal_code region       product_id         category sub-category  \
# 1401      24153.0  South  OFF-EN-10002230  Office Supplies    Envelopes
#
#            product_name   sales  quantity  discount    profit
# 1401  Airmail Envelopes  251.79         3       0.0  118.3413

# %% [markdown]
# 4. **FILTER** the dataset where the customer is: `Roy Französisch`

# %%
roy = df[df["customer_name"]=="Roy Französisch"]
roy
# Out:
#             order_id order_date ship_date       ship_mode customer_id  \
# 404   CA-2018-117933   12/24/18  12/29/18  Standard Class    RF-19840
# 1494  CA-2015-123925   12/17/15  12/19/15    Second Class    RF-19840
# 1862  CA-2015-151078   11/12/15  11/12/15        Same Day    RF-19840
# 2362  CA-2018-136497    4/16/18   4/20/18  Standard Class    RF-19840
# 5576  CA-2017-136686   12/12/17  12/16/17  Standard Class    RF-19840
# 5577  CA-2017-136686   12/12/17  12/16/17  Standard Class    RF-19840
# 7779  CA-2017-139381    4/18/17   4/22/17  Standard Class    RF-19840
# 7780  CA-2017-139381    4/18/17   4/22/17  Standard Class    RF-19840
# 7924  CA-2017-125843    8/13/17   8/16/17     First Class    RF-19840
# 7925  CA-2017-125843    8/13/17   8/16/17     First Class    RF-19840
# 9875  CA-2016-130855   12/29/16    1/5/17  Standard Class    RF-19840
#
#         customer_name   segment        country           city       state  \
# 404   Roy Französisch  Consumer  United States  New York City    New York
# 1494  Roy Französisch  Consumer  United States       Columbus     Georgia
# 1862  Roy Französisch  Consumer  United States    San Antonio       Texas
# 2362  Roy Französisch  Consumer  United States       Columbus        Ohio
# 5576  Roy Französisch  Consumer  United States       Pasadena  California
# 5577  Roy Französisch  Consumer  United States       Pasadena  California
# 7779  Roy Französisch  Consumer  United States     Chesapeake    Virginia
# 7780  Roy Französisch  Consumer  United States     Chesapeake    Virginia
# 7924  Roy Französisch  Consumer  United States    Springfield    Virginia
# 7925  Roy Französisch  Consumer  United States    Springfield    Virginia
# 9875  Roy Französisch  Consumer  United States  New York City    New York
#
#       postal_code   region       product_id         category sub-category  \
# 404       10024.0     East  OFF-AP-10004249  Office Supplies   Appliances
# 1494      31907.0    South  OFF-AR-10002952  Office Supplies          Art
# 1862      78207.0  Central  OFF-ST-10001328  Office Supplies      Storage
# 2362      43229.0     East  OFF-BI-10001553  Office Supplies      Binders
# 5576      91104.0     West  FUR-FU-10004864        Furniture  Furnishings
# 5577      91104.0     West  OFF-AP-10002350  Office Supplies   Appliances
# 7779      23320.0    South  OFF-AP-10001271  Office Supplies   Appliances
# 7780      23320.0    South  TEC-PH-10004924       Technology       Phones
# 7924      22153.0    South  OFF-BI-10002309  Office Supplies      Binders
# 7925      22153.0    South  OFF-LA-10003923  Office Supplies       Labels
# 9875      10035.0     East  OFF-SU-10003936  Office Supplies     Supplies
#
#                                            product_name    sales  quantity  \
# 404                                       Staple holder   35.910         3
# 1494     Stanley Contemporary Battery Pencil Sharpeners   40.050         3
# 1862          Personal Filing Tote with Lid, Black/Gray   49.632         4
# 2362  SpineVue Locking Slant-D Ring Binders by Cardinal   13.710         5
# 5576  Howard Miller 14-1/2" Diameter Chrome Round Wa...  383.640         6
# 5577  Belkin F9H710-06 7 Outlet SurgeMaster Surge Pr...   56.520         3
# 7779    Eureka The Boss Cordless Rechargeable Stick Vac  203.920         4
# 7780  SKILCRAFT Telephone Shoulder Rest, 2" x 6.5" x...   29.560         4
# 7924    Avery Heavy-Duty EZD  Binder With Locking Rings   22.320         4
# 7925             Alphabetical Labels for Top Tab Filing  103.600         7
# 9875                  Acme Serrated Blade Letter Opener    6.360         2
#
#       discount    profit
# 404        0.0    9.6957
# 1494       0.0   11.2140
# 1862       0.2    4.9632
# 2362       0.7  -10.0540
# 5576       0.0  122.7648
# 5577       0.0   15.8256
# 7779       0.0   55.0584
# 7780       0.0    7.9812
# 7924       0.0   10.7136
# 7925       0.0   51.8000
# 9875       0.0    0.0636

# %% [markdown]
# 5. **CREATE a SUBSET** of the dataframe with the columns: `Ship Mode`, `Segment`, `Country`, `Category`, `Profit`

# %%
df_subset = df[["ship_mode","segment","country","category","profit"]]
df_subset.head()
# Out:
#         ship_mode    segment        country         category    profit
# 0    Second Class   Consumer  United States        Furniture   41.9136
# 1    Second Class   Consumer  United States        Furniture  219.5820
# 2    Second Class  Corporate  United States  Office Supplies    6.8714
# 3  Standard Class   Consumer  United States        Furniture -383.0310
# 4  Standard Class   Consumer  United States  Office Supplies    2.5164

# %% [markdown]
# 6. **CALCULATE** the SUM of the profit: it should be a formatted print() the says `Roy Französisch amounted a total profit of X $`

# %%
roy_profit = sum(list(roy["profit"]))
#roy_profit = np.sum(roy["profit"])
print(f"Roy Französisch amounted a total profit of {roy_profit} $")
# Out:
# Roy Französisch amounted a total profit of 280.02610000000004 $

# %% [markdown]
# 7. **EXPORT** the csv with the name: `customer_example.csv`

# %%
roy_df.to_csv("../Documents/Ironhack/bootcamp/lectures/datasets/customer_example.csv")

# %% [markdown]
# 8. **DEFINE** (ENCAPSULATE) into a FUNCTION
#     - Function name: profit_per_customer
#     - Function args: name, string. the name of the customer to filter by
#         - to do this, you will have to change the line where you filter to change the literal "Roy Französisch" for name
#         - also change it in the formatted print
#     - Function should do steps: 1-8
#     - include the line: `df_imported = pd.read_csv("customer_example.csv")`
#     - Function return: it should return the `df_imported`

# %%
def profit_per_customer(name):
    dataset = pd.read_csv("../Documents/Ironhack/bootcamp/lectures/datasets/superstore.csv")
    df = pd.DataFrame(dataset)
    df.columns = [i.lower().replace(" ","_") for i in df.columns]
    df.drop(columns="row_id",inplace=True)
    client_df = df[df["customer_name"]==name]
    client_profit = sum(list(client_df["profit"]))
    print(f"{name} amounted a total profit of {client_profit} $")
    client_df.to_csv("./customer_example.csv")
    #client_df.to_csv("./customer_example.csv",index=False)
    df_imported = pd.read_csv("customer_example.csv")
    return df_imported

# %% [markdown]
# 9. **CALL**: `df_claire = profit_per_customer("Roy Französisch")`

# %%
df_claire = profit_per_customer("Roy Französisch")
# Out:
# Roy Französisch amounted a total profit of 280.02610000000004 $

# %% [markdown]
# 10. **Run**: `df_claire`

# %%
df_claire
# Out:
#             order_id order_date ship_date       ship_mode customer_id  \
# 404   CA-2018-117933   12/24/18  12/29/18  Standard Class    RF-19840
# 1494  CA-2015-123925   12/17/15  12/19/15    Second Class    RF-19840
# 1862  CA-2015-151078   11/12/15  11/12/15        Same Day    RF-19840
# 2362  CA-2018-136497    4/16/18   4/20/18  Standard Class    RF-19840
# 5576  CA-2017-136686   12/12/17  12/16/17  Standard Class    RF-19840
# 5577  CA-2017-136686   12/12/17  12/16/17  Standard Class    RF-19840
# 7779  CA-2017-139381    4/18/17   4/22/17  Standard Class    RF-19840
# 7780  CA-2017-139381    4/18/17   4/22/17  Standard Class    RF-19840
# 7924  CA-2017-125843    8/13/17   8/16/17     First Class    RF-19840
# 7925  CA-2017-125843    8/13/17   8/16/17     First Class    RF-19840
# 9875  CA-2016-130855   12/29/16    1/5/17  Standard Class    RF-19840
#
#         customer_name   segment        country           city       state  \
# 404   Roy Französisch  Consumer  United States  New York City    New York
# 1494  Roy Französisch  Consumer  United States       Columbus     Georgia
# 1862  Roy Französisch  Consumer  United States    San Antonio       Texas
# 2362  Roy Französisch  Consumer  United States       Columbus        Ohio
# 5576  Roy Französisch  Consumer  United States       Pasadena  California
# 5577  Roy Französisch  Consumer  United States       Pasadena  California
# 7779  Roy Französisch  Consumer  United States     Chesapeake    Virginia
# 7780  Roy Französisch  Consumer  United States     Chesapeake    Virginia
# 7924  Roy Französisch  Consumer  United States    Springfield    Virginia
# 7925  Roy Französisch  Consumer  United States    Springfield    Virginia
# 9875  Roy Französisch  Consumer  United States  New York City    New York
#
#       postal_code   region       product_id         category sub-category  \
# 404       10024.0     East  OFF-AP-10004249  Office Supplies   Appliances
# 1494      31907.0    South  OFF-AR-10002952  Office Supplies          Art
# 1862      78207.0  Central  OFF-ST-10001328  Office Supplies      Storage
# 2362      43229.0     East  OFF-BI-10001553  Office Supplies      Binders
# 5576      91104.0     West  FUR-FU-10004864        Furniture  Furnishings
# 5577      91104.0     West  OFF-AP-10002350  Office Supplies   Appliances
# 7779      23320.0    South  OFF-AP-10001271  Office Supplies   Appliances
# 7780      23320.0    South  TEC-PH-10004924       Technology       Phones
# 7924      22153.0    South  OFF-BI-10002309  Office Supplies      Binders
# 7925      22153.0    South  OFF-LA-10003923  Office Supplies       Labels
# 9875      10035.0     East  OFF-SU-10003936  Office Supplies     Supplies
#
#                                            product_name    sales  quantity  \
# 404                                       Staple holder   35.910         3
# 1494     Stanley Contemporary Battery Pencil Sharpeners   40.050         3
# 1862          Personal Filing Tote with Lid, Black/Gray   49.632         4
# 2362  SpineVue Locking Slant-D Ring Binders by Cardinal   13.710         5
# 5576  Howard Miller 14-1/2" Diameter Chrome Round Wa...  383.640         6
# 5577  Belkin F9H710-06 7 Outlet SurgeMaster Surge Pr...   56.520         3
# 7779    Eureka The Boss Cordless Rechargeable Stick Vac  203.920         4
# 7780  SKILCRAFT Telephone Shoulder Rest, 2" x 6.5" x...   29.560         4
# 7924    Avery Heavy-Duty EZD  Binder With Locking Rings   22.320         4
# 7925             Alphabetical Labels for Top Tab Filing  103.600         7
# 9875                  Acme Serrated Blade Letter Opener    6.360         2
#
#       discount    profit
# 404        0.0    9.6957
# 1494       0.0   11.2140
# 1862       0.2    4.9632
# 2362       0.7  -10.0540
# 5576       0.0  122.7648
# 5577       0.0   15.8256
# 7779       0.0   55.0584
# 7780       0.0    7.9812
# 7924       0.0   10.7136
# 7925       0.0   51.8000
# 9875       0.0    0.0636

# %% [markdown]
# 11. **Re-use your own function**: how much did `Erica Smith` amounted in profit? Make sure you save it into a variable named `df_erica_smith`

# %%
df_erica_smith = profit_per_customer("Erica Smith")
df_erica_smith
# Out:
# Erica Smith amounted a total profit of 1003.2935000000001 $
#             order_id order_date ship_date       ship_mode customer_id  \
# 793   CA-2015-156433    9/20/15   9/26/15  Standard Class    ES-14020
# 794   CA-2015-156433    9/20/15   9/26/15  Standard Class    ES-14020
# 2757  CA-2017-127775    6/11/17   6/13/17    Second Class    ES-14020
# 4752  CA-2018-103499   11/20/18  11/24/18  Standard Class    ES-14020
# 5990  US-2018-163300    9/15/18   9/21/18  Standard Class    ES-14020
# 5991  US-2018-163300    9/15/18   9/21/18  Standard Class    ES-14020
# 5992  US-2018-163300    9/15/18   9/21/18  Standard Class    ES-14020
# 6167  CA-2016-142433    4/20/16   4/25/16  Standard Class    ES-14020
#
#      customer_name   segment        country           city       state  \
# 793    Erica Smith  Consumer  United States  San Francisco  California
# 794    Erica Smith  Consumer  United States  San Francisco  California
# 2757   Erica Smith  Consumer  United States  New York City    New York
# 4752   Erica Smith  Consumer  United States        Jackson   Tennessee
# 5990   Erica Smith  Consumer  United States    Los Angeles  California
# 5991   Erica Smith  Consumer  United States    Los Angeles  California
# 5992   Erica Smith  Consumer  United States    Los Angeles  California
# 6167   Erica Smith  Consumer  United States        Houston       Texas
#
#       postal_code   region       product_id         category sub-category  \
# 793       94110.0     West  OFF-LA-10001569  Office Supplies       Labels
# 794       94110.0     West  OFF-PA-10003724  Office Supplies        Paper
# 2757      10035.0     East  TEC-AC-10002402       Technology  Accessories
# 4752      38301.0    South  FUR-CH-10001482        Furniture       Chairs
# 5990      90049.0     West  OFF-BI-10004390  Office Supplies      Binders
# 5991      90049.0     West  TEC-PH-10001700       Technology       Phones
# 5992      90049.0     West  FUR-CH-10003396        Furniture       Chairs
# 6167      77036.0  Central  OFF-PA-10002377  Office Supplies        Paper
#
#                                            product_name     sales  quantity  \
# 793                                           Avery 499     9.960         2
# 794                  Wirebound Message Book, 4 per Page    21.720         4
# 2757     Razer Kraken PRO Over Ear PC and Music Headset   239.970         3
# 4752  Office Star - Mesh Screen back chair with Viny...   209.568         2
# 5990            GBC DocuBind 200 Manual Binding Machine  2357.488         7
# 5991  Panasonic KX-TG6844B Expandable Digital Cordle...   369.544         7
# 5992                          Global Deluxe Steno Chair   184.752         3
# 6167                                         Xerox 1916   117.456         3
#
#       discount    profit
# 793        0.0    4.5816
# 794        0.0   10.6428
# 2757       0.0   71.9910
# 4752       0.2  -23.5764
# 5990       0.2  884.0580
# 5991       0.2   32.3351
# 5992       0.2  -20.7846
# 6167       0.2   44.0460

# %% [markdown]
# ## BONUS I

# %% [markdown]
# 11. Create, on the same location as this notebook, a python file named `filtering.py`.

# %% [markdown]
# 12. Copy and paste your function into it

# %% [markdown]
# 13. At the top of the file, make sure you have the necessary imports

# %% [markdown]
# 14. Save your file. Close it. Go to Terminal and navigate to the location where the pythn file is. Run `python filtering.py`.
#
# - Module not found: pandas ? Make sure you're in the correct environment before executing the previous command.

# %% [markdown]
# ## BONUS II

# %% [markdown]
# 15. Import os. Inside of the python function, run bash code through python to open the exporte .csv file and run the python file again. You should expect the transformed csv file to open on your computer once it has been transformed.
